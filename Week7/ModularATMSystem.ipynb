# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/Week7/ModularATMSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)


# FUNCTION DEFINITIONS
# 1. Define verify_pin():

def verify_pin():
 while True:
  pin = 1234
  user_pin = int(input("Please enter your pin: "))
#   --create a loop that asks for a PIN until it equals "1234"
  if user_pin == pin:
    print("Your pin has been accepted!")
    break
  else:
    print("Incorrect, try again!")

# 2. Define withdraw(balance, amount):
def withdraw(balance, amount):
  if amount <= balance:
    remaining_balance = balance - amount
    print("Withdrawal succesfull!")
    return remaining_balance
  else:
    print("Insufficent funds, withdrawal not approved!")
    return balance

#   --check if enough money exists
#   --return the new (or old) balance

# PROGRAM LOGIC
# 1. Set current_balance to 500

balance = 500

# 2. Call verify_pin()

verify_pin()

# 3. Get withdrawal amount from user input

amount = float(input("Enter withdrawal amount: "))

# 4. Update current_balance by calling withdraw()

balance = withdraw(balance, amount)

# 5. Print the final balance

print("Current balance: $" + str(balance))
# Out:
# Please enter your pin: 2345
# Incorrect, try again!
# Please enter your pin: 1234
# Your pin has been accepted!
# Enter withdrawal amount: 231.85
# Withdrawal succesfull!
# Current balance: $268.15
