# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/Week14/Week14_LibraryManager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name: library.py

###### IMPORT STATEMENTS ######
# NONE


###### CLASS DEFINITIONS ######

# Create a class called "Book"
class Book:
  # Initialize using (__init__) method; with parameters self, title, author
  def __init__(self, title, author):
    # Define each attribute
    self.title = title
    self.author = author
    # Create a third attribute (is_available), with the default being "True"
    self.is_available = True

  # Use the (__str__) method, with "self" as the parameter
    # If book is available
      # Status = Available
    # Else
      # Status = Unavailable
    # return a statement that shows the book title and its availability

  # Create a class method called checkout
    # Change is_available to "False"

  # Create a class method called return_book
    # Change is_available to True


###### PROGRAM LOGIC ######

# Create two separate instances of the Book Class, entering in the appropriate parameters
Book_1 = Book("The Handmaid's Tale", "Margaret Atwood")
print(Book_1.title)
# Print the availability of Book 1; showing title as well

# Print the availability of Book 2; showing the title too

# Checkout one of the books by calling the checkout() function & using dot notation

# Print status of Book 1 & 2 again to show the change
# Out:
# The Handmaid's Tale
