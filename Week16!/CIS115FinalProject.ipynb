# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/Week16!/CIS115FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Expense Tracker #


# IMPORT STATEMENTS #
# Import the datetime module
import datetime
from datetime import datetime

# FUNCTION DEFINITIONS #

# Create a function that filters expenses by categories or vendors with parameters of the dictionary and the filter (key) and its value
  # Create a list to hold filtered expenses
  # Create a "for" loop to find the expense in the expense list dictionary
    # First, determine if there are items under the category or vendor
      # If it exists, add it to the filtered list
    # Return the filtered list


# Create a function that displays the user's expenses with the expense_list as the parameter
  # First check if the list has expenses in it
    # If not, print "No expenses to display"
    # return
  # print the expense display header ("Your Expenses:")
  # Create a for loop that goes through each expense and numbers it
    # Print the list by outlining the category, vendor, amount, and date of each expense

# PROGRAM LOGIC #

# Create a list to store the different expense dictionaries (vendor, category, date, amount)

expenses = []

# Create a while loop that will provide the user with a menu and will break once the user types the number option for "exit"
  # While True:
while True:
    # Print the different options in the menu and create a header: "expense tracker", "add new expenses", "get totals", and "exit"
    print("--- Expense Tracker Menu: ----")
    print(
        "1. Add new expenses\n"
        "2. Specific Total (Vendor/Category)\n"
        "3. Total Expenses\n"
        "4. Exit" )
    # Ask for user input and initialize it as "choice"
    choice = int(input("Please select an option (1-4) to get started: "))
      # if choice = 1
    if choice == 1:
        # Ask user for category, vendor, amount (float), and date
        category = input("Please enter the category of the expense: ")
        vendor = input("Please enter the vendor of the expense: ")
        amount = float(input("Please enter the amount of the expense: "))

        # Get date input as a string and put it into a datetime object
        date_str = input("Please enter the date of the expense (MM/DD/YYYY): ")
        # Assistance from AI with this part
        try:
            date = datetime.strptime(date_str, '%m/%d/%Y').date() # Store only the date part
        except ValueError:
            print("Invalid date format. Please use MM/DD/YYYY.")
            # Skip to the next iteration of the loop
            continue

        # Create a dictionary for the expense being added, separated by category
        current_expense = {
            "category": category,
            "vendor": vendor,
            "amount": amount,
            "date": date
        }
        # Append the expense to the expenses list
        expenses.append(current_expense)

        print(f"Expense added: Category: {category}, Vendor: {vendor}, Amount: {amount}, Date: {date}")
        print(expenses)

      # elif choice = 2
        # Ask user what total they would like (all, by category, by vendor)
      # elif choice = 3
        # total = sum of the amounts in expenses dictionary
        # print total
      # else
        # Print "Goodbye!"
        # Break the loop
# Out:
# --- Expense Tracker Menu: ----
# 1. Add new expenses
# 2. Specific Total (Vendor/Category)
# 3. Total Expenses
# 4. Exit
# Please select an option (1-4) to get started: 1
# Please enter the category of the expense: Groceries
# Please enter the vendor of the expense: Harris Teeter
# Please enter the amount of the expense: 24.67
# Please enter the date of the expense (MM/DD/YYYY): 05/02/2026
# Expense added: Category: Groceries, Vendor: Harris Teeter, Amount: 24.67, Date: 2026-05-02
# [{'category': 'Groceries', 'vendor': 'Harris Teeter', 'amount': 24.67, 'date': datetime.date(2026, 5, 2)}]
# --- Expense Tracker Menu: ----
# 1. Add new expenses
# 2. Specific Total (Vendor/Category)
# 3. Total Expenses
# 4. Exit
# Please select an option (1-4) to get started: 1
# Please enter the category of the expense: Wifi Bill
# Please enter the vendor of the expense: Spectrum
# Please enter the amount of the expense: 50.25
# Please enter the date of the expense (MM/DD/YYYY): 05/01/2026
# Expense added: Category: Wifi Bill, Vendor: Spectrum, Amount: 50.25, Date: 2026-05-01
# [{'category': 'Groceries', 'vendor': 'Harris Teeter', 'amount': 24.67, 'date': datetime.date(2026, 5, 2)}, {'category': 'Wifi Bill', 'vendor': 'Spectrum', 'amount': 50.25, 'date': datetime.date(2026, 5, 1)}]
# --- Expense Tracker Menu: ----
# 1. Add new expenses
# 2. Specific Total (Vendor/Category)
# 3. Total Expenses
# 4. Exit
# Please select an option (1-4) to get started: 1
# Please enter the category of the expense: Gas
# Please enter the vendor of the expense: Wawa
# Please enter the amount of the expense: 60.72
# Please enter the date of the expense (MM/DD/YYYY): 05/02/2026
# Expense added: Category: Gas, Vendor: Wawa, Amount: 60.72, Date: 2026-05-02
# [{'category': 'Groceries', 'vendor': 'Harris Teeter', 'amount': 24.67, 'date': datetime.date(2026, 5, 2)}, {'category': 'Wifi Bill', 'vendor': 'Spectrum', 'amount': 50.25, 'date': datetime.date(2026, 5, 1)}, {'category': 'Gas', 'vendor': 'Wawa', 'amount': 60.72, 'date': datetime.date(2026, 5, 2)}]
# --- Expense Tracker Menu: ----
# 1. Add new expenses
# 2. Specific Total (Vendor/Category)
# 3. Total Expenses
# 4. Exit
