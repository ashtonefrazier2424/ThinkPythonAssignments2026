# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/Week5/CinemaAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)

age = int(input("Please enter your age:"))

def calculate_ticket(age, hour):

# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12

  if age <= 12 or age >= 65:
    price = 8
    print("Your ticket price is: $ " + str(price))
  else:
    price = 12
    print("Your ticket price is: $ " + str(price))

# 3. Logic: If hour < 17, subtract 2 from the price.
# 4. Print the final price.

calculate_ticket(age, 17)

# PROGRAM LOGIC
# 1. input() for age ()
# 2. input() for movie hour (int)
# 3. Call calculate_ticket()
# Out:
# Please enter your age:10
# Your ticket price is: $ 8
