# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/Week10/TeamRosterWeek10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py
# IMPORT STATEMENTS




# FUNCTION DEFINITIONS


# Add players to the list: (Roster, Player Name)
  # Create a while loop that asks users to enter a player's name
  # While True:
    # Add player's name to the roster using the append method (roster.append(player_name))
    # Loop breaks when user types "quit"


# Is on the roster: (Roster, Player Name)
  # if player name is on the list:
    # return True
  # else:
    # return false

# PROGRAM LOGIC

# Create an empty list titled "Roster"

# Ask user for input: "Enter player name (or 'quit' to stop):"
  # Make sure the user's input is not case sensitive
  # Call the add players to the list function(roster, player name)


# Ask user for input: "Who would you like to search for?"
  # Make sure user's input is not case sensitive
  # Call is on the roster function(roster, player name)


# result = is on the roster function

# Display findings to user:

# if result:
  # print("Result: Player found!")
# else:
  # print("Result: Player not found!")
