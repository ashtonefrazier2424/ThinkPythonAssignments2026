# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/Week4/Week4BioFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.

def print_bio( name, age, goal):

# 2. Inside the function, use string multiplication (*) for a border line.
  print("*" * 25)

# 3. Print the bio details using the parameter names.
  print("Name: " + name + " Age: " + str(age) + " Goal: " + goal )
  print ("*" * 25)

# PROGRAM LOGIC
# 1. Call print_bio using my own info.

print_bio("Ashton", 21, "To become a P.A." )

# 2. Call print_bio using [Name of a famous person].
# 3. Call print_bio using [Name of a fictional character].
# Out:
# *************************
# Name: Ashton Age: 21 Goal: To become a P.A.
# *************************
