# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/CinemaAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS

# 1. Define calculate_ticket(age, hour)

def calculate_ticket(age, hour):

  # 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12

  if age <= 12 or age >= 65:
    price = 8
  else:
    price = 12

  # 3. Logic: If hour < 17, subtract 2 from the price.

  if hour < 17:
    price = price - 2
    print("Hooray, you have received a discount!")
    print("Your ticket price is: $" + str(price))
  if hour >= 17:
    price = price
    print("Your ticket price is: $" + str(price))

  # 4. Print the final price.

    print("Enjoy your movie!")

# PROGRAM LOGIC

# 1. input() for age (int)

age = int(input("Please enter your age: "))

# 2. input() for movie hour (int)

hour = int(input("Please type the time of your movie in a 24-hour format:"))

# 3. Call calculate_ticket()

calculate_ticket(age, hour)
# Out:
# Please enter your age: 10
# Please type the time of your movie in a 24-hour format:16
# Hooray, you have received a discount!
# Your ticket price is: $6
