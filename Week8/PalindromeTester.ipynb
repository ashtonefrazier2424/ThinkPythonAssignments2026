# %% [markdown]
# <a href="https://colab.research.google.com/github/ashtonefrazier2424/ThinkPythonAssignments2026/blob/main/Week8/PalindromeTester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Import Statements ###
# NONE #


### Function Definitions ###

# Create a function, is_palindrome with one parameter, (word to be checked)
def is_palindrome(entered_word):
  # Reverse entered word using reverse slicing: word[::-1]
  reversed_text = entered_word[::-1]
  # If reversed word == original word:
  if reversed_text == entered_word:
    # Return True
    # Print the results using an f string, to show the entered word
    print(f"Yes, {entered_word} is a palindrome!")
  # Otherwise:
  else:
    # Return False
    # Print the results using an f string, to show the entered word
    print(f"No, {entered_word} is not a palindrome!")

### Program Logic ###

# Ask user to enter a word to check if it's a palindrome
  # use .upper method to make the program case insensitive: input("Command").lower

entered_word = input("Enter a word to determine if it's a palindrome: ").lower()

# Call a function to reverse the entered word to check if it's a palindrome

is_palindrome(entered_word)

# Print whether the entered word is (True) or is not (False) a palindrome
# Printing directly with the function, instead of as true or false
# Out:
# Enter a word to determine if it's a palindrome: Racecar
# Yes, racecar is a palindrome!
